# %% [markdown]
# # Evaluate Notebook\n
# Starter notebook for evaluating recognition outputs.

# %%
import requests\n
\n
base_url = 'http://localhost:8000'\n
health = requests.get(f'{base_url}/health', timeout=5).json()\n
health
