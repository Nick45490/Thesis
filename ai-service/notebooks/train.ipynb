# %% [markdown]
# # Train Notebook\n
# Starter notebook for training the car recognition model.

# %%
from pathlib import Path\n
import json\n
\n
root = Path('..').resolve()\n
labels_path = root / 'model' / 'class_labels.json'\n
labels = json.loads(labels_path.read_text(encoding='utf-8'))\n
len(labels), labels[:3]
